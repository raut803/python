# %% [markdown]
# <a href="https://colab.research.google.com/github/raut803/python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('laptops.csv', encoding = "ISO-8859-1", engine = "python")

# %%
df.head()
# Out:
#            Company      Product   TypeName  ...  OpSys  Weight Price_euros
# Unnamed: 0                                  ...
# 1            Apple  MacBook Pro  Ultrabook  ...  macOS  1.37kg     1339.69
# 2            Apple  Macbook Air  Ultrabook  ...  macOS  1.34kg      898.94
# 3               HP       250 G6   Notebook  ...  No OS  1.86kg      575.00
# 4            Apple  MacBook Pro  Ultrabook  ...  macOS  1.83kg     2537.45
# 5            Apple  MacBook Pro  Ultrabook  ...  macOS  1.37kg     1803.60
#
# [5 rows x 12 columns]

# %%
find_data = "full HD"

# %%
df["Full HD"] = df['ScreenResolution'].str.find(find_data)

# %%
df.head()
# Out:
#            Company      Product   TypeName  ...  Weight Price_euros Full HD
# Unnamed: 0                                  ...
# 1            Apple  MacBook Pro  Ultrabook  ...  1.37kg     1339.69      -1
# 2            Apple  Macbook Air  Ultrabook  ...  1.34kg      898.94      -1
# 3               HP       250 G6   Notebook  ...  1.86kg      575.00      -1
# 4            Apple  MacBook Pro  Ultrabook  ...  1.83kg     2537.45      -1
# 5            Apple  MacBook Pro  Ultrabook  ...  1.37kg     1803.60      -1
#
# [5 rows x 13 columns]

# %%
find_data = "IPS Panel"

# %%
df["IPS Panel"] = df["ScreenResolution"].str.find(find_data)

# %%
df.head()
# Out:
#            Company      Product   TypeName  ...  Price_euros Full HD IPS Panel
# Unnamed: 0                                  ...
# 1            Apple  MacBook Pro  Ultrabook  ...      1339.69      -1        -1
# 2            Apple  Macbook Air  Ultrabook  ...       898.94      -1        -1
# 3               HP       250 G6   Notebook  ...       575.00      -1        -1
# 4            Apple  MacBook Pro  Ultrabook  ...      2537.45      -1        -1
# 5            Apple  MacBook Pro  Ultrabook  ...      1803.60      -1        -1
#
# [5 rows x 14 columns]
